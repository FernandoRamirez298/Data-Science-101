# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as Rectangle

# %%
df = pd.read_csv('../../C03/Data/raw/data_kaggle.csv')

# %%
df.sample(5)
# Out:
#                                               Location         Price Rooms  \
# 30979                       Sri Petaling, Kuala Lumpur    RM 540,000     3
# 29607                Taman Tun Dr Ismail, Kuala Lumpur  RM 5,350,000     8
# 13512  Jalan Klang Lama (Old Klang Road), Kuala Lumpur  RM 2,000,000   4+1
# 9421                       Jalan Kuching, Kuala Lumpur    RM 360,000     3
# 49825                             Kepong, Kuala Lumpur    RM 720,000     4
#
#        Bathrooms  Car Parks         Property Type                      Size  \
# 30979        2.0        2.0  Condominium (EndLot)  Land area : 2034 sq. ft.
# 29607        6.0        NaN              Bungalow  Land area : 7188 sq. ft.
# 13512        5.0        4.0           Condominium  Built-up : 3,809 sq. ft.
# 9421         2.0        1.0    Apartment (Corner)  Built-up : 1,221 sq. ft.
# 49825        3.0        1.0           Condominium  Built-up : 1,400 sq. ft.
#
#              Furnishing
# 30979   Fully Furnished
# ...

# %%
df.tail(10)
# Out:
#                                               Location         Price Rooms  \
# 53873                             Kepong, Kuala Lumpur    RM 499,000     3
# 53874                         Batu Caves, Kuala Lumpur    RM 480,000     3
# 53875  Jalan Klang Lama (Old Klang Road), Kuala Lumpur    RM 475,000     3
# 53876                       Sri Hartamas, Kuala Lumpur  RM 2,700,000   4+2
# 53877                         Mont Kiara, Kuala Lumpur  RM 6,500,000   5+1
# 53878                            Bangsar, Kuala Lumpur  RM 5,100,000   5+1
# 53879                            Bangsar, Kuala Lumpur  RM 5,000,000     5
# 53880                            Bangsar, Kuala Lumpur  RM 5,500,000   5+1
# 53881                        Wangsa Maju, Kuala Lumpur    RM 480,000     3
# 53882                            Setapak, Kuala Lumpur    RM 540,000     4
#
#        Bathrooms  Car Parks                            Property Type  \
# 53873        2.0        NaN  1-sty Terrace/Link House (Intermediate)
# ...

# %%
df.head(100)
# Out:
#                              Location         Price Rooms  Bathrooms  \
# 0                  KLCC, Kuala Lumpur  RM 1,250,000   2+1        3.0
# 1     Damansara Heights, Kuala Lumpur  RM 6,800,000     6        7.0
# 2               Dutamas, Kuala Lumpur  RM 1,030,000     3        4.0
# 3                Cheras, Kuala Lumpur           NaN   NaN        NaN
# 4           Bukit Jalil, Kuala Lumpur    RM 900,000   4+1        3.0
# ..                                ...           ...   ...        ...
# 95                 KLCC, Kuala Lumpur  RM 2,300,000     1        1.0
# 96  Taman Tun Dr Ismail, Kuala Lumpur  RM 4,995,000   5+1        7.0
# 97  Taman Tun Dr Ismail, Kuala Lumpur  RM 1,630,000     4        3.0
# 98           Mont Kiara, Kuala Lumpur  RM 1,850,000   4+1        4.0
# 99               Cheras, Kuala Lumpur           NaN   NaN        NaN
#
#     Car Parks                            Property Type  \
# 0         2.0                       Serviced Residence
# ...

# %% [markdown]
# # Valores Faltantes

# %%
df.dropna()
# Out:
#                                 Location         Price Rooms  Bathrooms  \
# 0                     KLCC, Kuala Lumpur  RM 1,250,000   2+1        3.0
# 2                  Dutamas, Kuala Lumpur  RM 1,030,000     3        4.0
# 4              Bukit Jalil, Kuala Lumpur    RM 900,000   4+1        3.0
# 5      Taman Tun Dr Ismail, Kuala Lumpur  RM 5,350,000   4+2        5.0
# 7      Taman Tun Dr Ismail, Kuala Lumpur  RM 2,600,000     5        4.0
# ...                                  ...           ...   ...        ...
# 53862              Seputeh, Kuala Lumpur    RM 750,000     3        2.0
# 53868           KL Sentral, Kuala Lumpur  RM 1,400,000   3+1        3.0
# 53869          KL Eco City, Kuala Lumpur    RM 880,000     1        1.0
# 53876         Sri Hartamas, Kuala Lumpur  RM 2,700,000   4+2        6.0
# 53882              Setapak, Kuala Lumpur    RM 540,000     4        2.0
#
#        Car Parks               Property Type                      Size  \
# ...

# %%
df.fillna(0)
# Out:
#                               Location         Price Rooms  Bathrooms  \
# 0                   KLCC, Kuala Lumpur  RM 1,250,000   2+1        3.0
# 1      Damansara Heights, Kuala Lumpur  RM 6,800,000     6        7.0
# 2                Dutamas, Kuala Lumpur  RM 1,030,000     3        4.0
# 3                 Cheras, Kuala Lumpur             0     0        0.0
# 4            Bukit Jalil, Kuala Lumpur    RM 900,000   4+1        3.0
# ...                                ...           ...   ...        ...
# 53878            Bangsar, Kuala Lumpur  RM 5,100,000   5+1        4.0
# 53879            Bangsar, Kuala Lumpur  RM 5,000,000     5        4.0
# 53880            Bangsar, Kuala Lumpur  RM 5,500,000   5+1        4.0
# 53881        Wangsa Maju, Kuala Lumpur    RM 480,000     3        2.0
# 53882            Setapak, Kuala Lumpur    RM 540,000     4        2.0
#
#        Car Parks               Property Type                       Size  \
# ...

# %% [markdown]
# ## Seleccion de Filas y columnas

# %%
print (type(df['Location']),type(def[['Location']]))


display(df['Location'], head(5))
# Out:
#   Cell In[44], line 1
#     print (type(df['Location']),type(def[['Location']]))
#                                      ^
# SyntaxError: invalid syntax

# %%
df[['Rooms']]
# Out:
#       Rooms
# 0       2+1
# 1         6
# 2         3
# 3       NaN
# 4       4+1
# ...     ...
# 53878   5+1
# 53879     5
# 53880   5+1
# 53881     3
# 53882     4
#
# [53883 rows x 1 columns]

# %%
df.dropna(subset=['Size','Car Parks']) #dropea las filas que tengan NaN en las columnas size y Car parks
# Out:
#                                 Location         Price Rooms  Bathrooms  \
# 0                     KLCC, Kuala Lumpur  RM 1,250,000   2+1        3.0
# 2                  Dutamas, Kuala Lumpur  RM 1,030,000     3        4.0
# 4              Bukit Jalil, Kuala Lumpur    RM 900,000   4+1        3.0
# 5      Taman Tun Dr Ismail, Kuala Lumpur  RM 5,350,000   4+2        5.0
# 7      Taman Tun Dr Ismail, Kuala Lumpur  RM 2,600,000     5        4.0
# ...                                  ...           ...   ...        ...
# 53864          Kuchai Lama, Kuala Lumpur    RM 585,000   3+1        3.0
# 53868           KL Sentral, Kuala Lumpur  RM 1,400,000   3+1        3.0
# 53869          KL Eco City, Kuala Lumpur    RM 880,000     1        1.0
# 53876         Sri Hartamas, Kuala Lumpur  RM 2,700,000   4+2        6.0
# 53882              Setapak, Kuala Lumpur    RM 540,000     4        2.0
#
#        Car Parks               Property Type                      Size  \
# ...

# %%
df[['Location','Rooms','Car Parks']] # se pasa una lista como argunmente para seleccionar una lista de columnas
# Out:
#                               Location Rooms
# 0                   KLCC, Kuala Lumpur   2+1
# 1      Damansara Heights, Kuala Lumpur     6
# 2                Dutamas, Kuala Lumpur     3
# 3                 Cheras, Kuala Lumpur   NaN
# 4            Bukit Jalil, Kuala Lumpur   4+1
# ...                                ...   ...
# 53878            Bangsar, Kuala Lumpur   5+1
# 53879            Bangsar, Kuala Lumpur     5
# 53880            Bangsar, Kuala Lumpur   5+1
# 53881        Wangsa Maju, Kuala Lumpur     3
# 53882            Setapak, Kuala Lumpur     4
#
# [53883 rows x 2 columns]

# %%
#primero, las filas a seleccionar como arg. Seg arg columnas a seleccionar. Para este caso selcciona todas las filas y columnas
df.loc[:,:]
# Out:
#                               Location         Price Rooms  Bathrooms  \
# 0                   KLCC, Kuala Lumpur  RM 1,250,000   2+1        3.0
# 1      Damansara Heights, Kuala Lumpur  RM 6,800,000     6        7.0
# 2                Dutamas, Kuala Lumpur  RM 1,030,000     3        4.0
# 3                 Cheras, Kuala Lumpur           NaN   NaN        NaN
# 4            Bukit Jalil, Kuala Lumpur    RM 900,000   4+1        3.0
# ...                                ...           ...   ...        ...
# 53878            Bangsar, Kuala Lumpur  RM 5,100,000   5+1        4.0
# 53879            Bangsar, Kuala Lumpur  RM 5,000,000     5        4.0
# 53880            Bangsar, Kuala Lumpur  RM 5,500,000   5+1        4.0
# 53881        Wangsa Maju, Kuala Lumpur    RM 480,000     3        2.0
# 53882            Setapak, Kuala Lumpur    RM 540,000     4        2.0
#
#        Car Parks               Property Type                       Size  \
# ...

# %%
#Selecciona las filas de la 10 a la 15 y todas las columnas
df.loc[10:15,:]
# Out:
#                              Location         Price Rooms  Bathrooms  \
# 10         Ampang Hilir, Kuala Lumpur           NaN   NaN        NaN
# 11  Taman Tun Dr Ismail, Kuala Lumpur  RM 1,680,000     4        3.0
# 12  Taman Tun Dr Ismail, Kuala Lumpur  RM 1,700,000   3+1        3.0
# 13  Taman Tun Dr Ismail, Kuala Lumpur  RM 4,580,000   6+1        5.0
# 14          Bukit Jalil, Kuala Lumpur           NaN   NaN        NaN
# 15  Taman Tun Dr Ismail, Kuala Lumpur  RM 3,100,000   4+1        3.0
#
#     Car Parks                            Property Type  \
# 10        NaN                                      NaN
# 11        NaN  2-sty Terrace/Link House (Intermediate)
# 12        NaN  2-sty Terrace/Link House (Intermediate)
# 13        5.0                  Bungalow (Intermediate)
# 14        NaN                                      NaN
# 15        NaN       Semi-detached House (Intermediate)
#
#                            Size        Furnishing
# ...

# %%
#Selecciona las filas de la 10 a la 15 y las col. Location,Rooms,Car Parks. Hace referencia a los nombres, no a las posiciones
df.loc[10:15,['Location','Rooms','Car Parks']]
# Out:
#                              Location Rooms  Car Parks
# 10         Ampang Hilir, Kuala Lumpur   NaN        NaN
# 11  Taman Tun Dr Ismail, Kuala Lumpur     4        NaN
# 12  Taman Tun Dr Ismail, Kuala Lumpur   3+1        NaN
# 13  Taman Tun Dr Ismail, Kuala Lumpur   6+1        5.0
# 14          Bukit Jalil, Kuala Lumpur   NaN        NaN
# 15  Taman Tun Dr Ismail, Kuala Lumpur   4+1        NaN

# %%
# selecciona todas las filas y las columnas respecto a la posicion en el arreglo de 2 dimensiones
df.iloc[10:20,:]
# Out:
#                                    Location         Price Rooms  Bathrooms  \
# 10               Ampang Hilir, Kuala Lumpur           NaN   NaN        NaN
# 11        Taman Tun Dr Ismail, Kuala Lumpur  RM 1,680,000     4        3.0
# 12        Taman Tun Dr Ismail, Kuala Lumpur  RM 1,700,000   3+1        3.0
# 13        Taman Tun Dr Ismail, Kuala Lumpur  RM 4,580,000   6+1        5.0
# 14                Bukit Jalil, Kuala Lumpur           NaN   NaN        NaN
# 15        Taman Tun Dr Ismail, Kuala Lumpur  RM 3,100,000   4+1        3.0
# 16  Bukit Tunku (Kenny Hills), Kuala Lumpur  RM 9,000,000   6+1        7.0
# 17          Damansara Heights, Kuala Lumpur  RM 4,500,000   5+1        7.0
# 18                 Mont Kiara, Kuala Lumpur  RM 1,780,000   4+1        4.0
# 19                 Mont Kiara, Kuala Lumpur  RM 3,450,000   4+1        6.0
#
#     Car Parks                            Property Type  \
# 10        NaN                                      NaN
# ...

# %%
muestra = df.sample(10)
muestra.head(10)
# Out:
#                                               Location         Price Rooms  \
# 34172                         Mont Kiara, Kuala Lumpur  RM 2,800,000   4+2
# 49773                            Bangsar, Kuala Lumpur  RM 2,200,000   3+1
# 9043   Jalan Klang Lama (Old Klang Road), Kuala Lumpur    RM 610,000     2
# 21244                            Bangsar, Kuala Lumpur  RM 1,998,000   3+1
# 10727                      Desa ParkCity, Kuala Lumpur  RM 2,450,000     4
# 20201  Jalan Klang Lama (Old Klang Road), Kuala Lumpur  RM 1,550,000   3+1
# 30192                             Cheras, Kuala Lumpur  RM 1,000,000   4+1
# 48878                            Bangsar, Kuala Lumpur  RM 6,500,000     6
# 24734                            Bangsar, Kuala Lumpur  RM 2,200,000   3+1
# 25054                             Ampang, Kuala Lumpur  RM 1,200,000     4
#
#        Bathrooms  Car Parks                            Property Type  \
# 34172        6.0        NaN                     Condominium (Corner)
# ...

# %%
#Tira error porque no encuentra el '0' en la col de indice
muestra.loc[0:10,:]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
muestra.iloc[0:10,:]
# Out:
#                                               Location         Price Rooms  \
# 34172                         Mont Kiara, Kuala Lumpur  RM 2,800,000   4+2
# 49773                            Bangsar, Kuala Lumpur  RM 2,200,000   3+1
# 9043   Jalan Klang Lama (Old Klang Road), Kuala Lumpur    RM 610,000     2
# 21244                            Bangsar, Kuala Lumpur  RM 1,998,000   3+1
# 10727                      Desa ParkCity, Kuala Lumpur  RM 2,450,000     4
# 20201  Jalan Klang Lama (Old Klang Road), Kuala Lumpur  RM 1,550,000   3+1
# 30192                             Cheras, Kuala Lumpur  RM 1,000,000   4+1
# 48878                            Bangsar, Kuala Lumpur  RM 6,500,000     6
# 24734                            Bangsar, Kuala Lumpur  RM 2,200,000   3+1
# 25054                             Ampang, Kuala Lumpur  RM 1,200,000     4
#
#        Bathrooms  Car Parks                            Property Type  \
# 34172        6.0        NaN                     Condominium (Corner)
# ...

# %% [markdown]
# ## Modificacion de variables

# %%
df_copy= df.copy()

# %%
df_copy['Bathrooms'] +1
# Out:
# 0        4.0
# 1        8.0
# 2        5.0
# 3        NaN
# 4        4.0
#         ...
# 53878    5.0
# 53879    5.0
# 53880    5.0
# 53881    3.0
# 53882    3.0
# Name: Bathrooms, Length: 53883, dtype: float64

# %%
muestra = df_copy.sample(10).copy()
