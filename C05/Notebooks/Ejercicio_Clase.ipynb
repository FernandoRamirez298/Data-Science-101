# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as Rectangle
import datetime as dt
import seaborn as sns

# %%
df_D= pd.read_csv('../../C05/Data/D.csv')
df_DUK= pd.read_csv('../../C05/Data/DUK.csv')
df_EXC= pd.read_csv('../../C05/Data/EXC.csv')
df_NEE= pd.read_csv('../../C05/Data/NEE.csv')
df_SO= pd.read_csv('../../C05/Data/SO.csv')


df_D["Datafreme"] = "D"
df_DUK["Datafreme"] = "DUK"
df_EXC["Datafreme"] = "EXC"
df_NEE["Datafreme"] = "NEE"
df_SO["Datafreme"] = "SO"

df = [df_D,df_DUK,df_EXC,df_NEE,df_SO]

# %%
df_final = pd.concat(df)
df_final
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2014-07-28  69.750000  71.059998  69.750000  70.879997  57.963978
# 1     2014-07-29  70.669998  70.980003  69.930000  69.930000  57.187099
# 2     2014-07-30  70.000000  70.660004  68.400002  68.970001  56.402020
# 3     2014-07-31  68.629997  68.849998  67.580002  67.639999  55.314388
# 4     2014-08-01  67.330002  68.410004  67.220001  67.589996  55.273487
# ...          ...        ...        ...        ...        ...        ...
# 1254  2019-07-22  55.400002  55.610001  54.869999  55.480000  55.480000
# 1255  2019-07-23  55.500000  55.619999  55.009998  55.419998  55.419998
# 1256  2019-07-24  55.459999  55.669998  55.099998  55.639999  55.639999
# 1257  2019-07-25  55.540001  55.810001  55.250000  55.360001  55.360001
# 1258  2019-07-26  55.340000  55.830002  55.200001  55.740002  55.740002
#
#        Volume Datafreme
# 0     1806400         D
# 1     2231100         D
# 2     2588900         D
# ...

# %%
df_final["Volatility"] = (df_final["High"] - df_final["Low"])/ df_final["Open"]

df_final["Return index"] = (df_final["Close"] / df_final["Open"])-1 


df_final
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2014-07-28  69.750000  71.059998  69.750000  70.879997  57.963978
# 1     2014-07-29  70.669998  70.980003  69.930000  69.930000  57.187099
# 2     2014-07-30  70.000000  70.660004  68.400002  68.970001  56.402020
# 3     2014-07-31  68.629997  68.849998  67.580002  67.639999  55.314388
# 4     2014-08-01  67.330002  68.410004  67.220001  67.589996  55.273487
# ...          ...        ...        ...        ...        ...        ...
# 1254  2019-07-22  55.400002  55.610001  54.869999  55.480000  55.480000
# 1255  2019-07-23  55.500000  55.619999  55.009998  55.419998  55.419998
# 1256  2019-07-24  55.459999  55.669998  55.099998  55.639999  55.639999
# 1257  2019-07-25  55.540001  55.810001  55.250000  55.360001  55.360001
# 1258  2019-07-26  55.340000  55.830002  55.200001  55.740002  55.740002
#
#        Volume Datafreme  Volatility  Return index
# 0     1806400         D    0.018781      0.016201
# ...

# %%
sns.histplot(y=df_final["Volatility"], x= df_final["Date"], hue= df_final["Datafreme"], multiple= "stack")
# Out:
# <AxesSubplot: xlabel='Date', ylabel='Volatility'>
# Canceled future for execute_request message before replies were done
# El Kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior. Revise el código de las celdas para identificar una posible causa del error. Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información. Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.
