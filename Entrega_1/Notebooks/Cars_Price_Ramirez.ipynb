# %% [markdown]
# # Abstract
#
# #### Se desea elaborar un analisis del mercado automotor en EEUU para poder predecir el precio de un auto relacionado a sus atributos mas importantes y llamativos, tanto esteticos como funcionales.

# %% [markdown]
# ### Objetivo

# %% [markdown]
# ####  Dataset 1: Cars Price Dataset
# ##### Predecir precio de un auto con ciertos atributos para poder elegir el que mejor se ajuste al presupuesto.
# ##### El dataset esta compuesto por un archivo que contiene datos de entrenamiento y otro archivo que contiene datos de prueba
# ##### Target ---> Price
# ##### Variables de interes principales: Manufacturer,Model,Prod. year,Category,Leather interior,Fuel type,Engine volume,Color,Airbags

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as Rectangle

# %%
df = pd.read_csv('/workspaces/Data-Science-101/Entrega_1/Data/Dataset1/Train/train.csv')

# %%
df.head(100)
# Out:
#           ID  Price  Levy   Manufacturer           Model  Prod. year  \
# 0   45654403  13328  1399          LEXUS          RX 450        2010
# 1   44731507  16621  1018      CHEVROLET         Equinox        2011
# 2   45774419   8467     -          HONDA             FIT        2006
# 3   45769185   3607   862           FORD          Escape        2011
# 4   45809263  11726   446          HONDA             FIT        2014
# ..       ...    ...   ...            ...             ...         ...
# 95  45330228  32929     -            BMW  428 Sport Line        2013
# 96  45776745  18817     -         NISSAN          Patrol        1990
# 97  45749534   4234     -          HONDA           Civic        1997
# 98  45789555  15053     -  MERCEDES-BENZ           E 320        2004
# 99  45797276  15458   966        HYUNDAI         Genesis        2009
#
#      Category Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# ...
